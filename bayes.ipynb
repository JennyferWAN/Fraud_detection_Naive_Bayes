# %%
import pandas

#lire le fichier csv
data = pandas.read_csv("/Users/jennyferwan/Desktop/ML_PREDICTIVE_MODELS_LESSONS/data/champignons.csv")
#affichier les 6 premiers échantillons
data.head(6)
# Out:
#   classe chapeau-forme chapeau-surface chapeau-couleur ecchymoses odeur  \
# 0      p             x               s               n          t     p
# 1      e             x               s               y          t     a
# 2      e             b               s               w          t     l
# 3      p             x               y               w          t     p
# 4      e             x               s               g          f     n
# 5      e             x               y               y          t     a
#
#   branchie-attachement branchie-espacement branchie-taille branchie-couleur  \
# 0                    f                   c               n                k
# 1                    f                   c               b                k
# 2                    f                   c               b                n
# 3                    f                   c               n                n
# 4                    f                   w               b                k
# 5                    f                   c               b                n
#
#    ... tige-surface-dessous-anneau tige-couleur-dessus-anneau  \
# 0  ...                           s                          w
# 1  ...                           s                          w
# 2  ...                           s                          w
# 3  ...                           s                          w
# 4  ...                           s                          w
# 5  ...                           s                          w
#
#   tige-couleur-dessous-anneau voile-type voile-couleur anneau-nombre  \
# 0                           w          p             w             o
# 1                           w          p             w             o
# 2                           w          p             w             o
# 3                           w          p             w             o
# 4                           w          p             w             o
# 5                           w          p             w             o
#
#   anneau-type spore-couleur population habitat
# 0           p             k          s       u
# 1           p             n          n       g
# 2           p             n          n       m
# 3           p             k          s       u
# 4           e             n          a       g
# 5           p             k          n       g
#
# [6 rows x 23 columns]

# %%
data.isnull().sum()
# Out:
# classe                         0
# chapeau-forme                  0
# chapeau-surface                0
# chapeau-couleur                0
# ecchymoses                     0
# odeur                          0
# branchie-attachement           0
# branchie-espacement            0
# branchie-taille                0
# branchie-couleur               0
# tige-forme                     0
# tige-racine                    0
# tige-surface-dessus-anneau     0
# tige-surface-dessous-anneau    0
# tige-couleur-dessus-anneau     0
# tige-couleur-dessous-anneau    0
# voile-type                     0
# voile-couleur                  0
# anneau-nombre                  0
# anneau-type                    0
# spore-couleur                  0
# population                     0
# habitat                        0
# dtype: int64

# %%
data['classe'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
data.shape
# Out:
# (8124, 23)

# %%
from sklearn.preprocessing import LabelEncoder

encodeur = LabelEncoder()
for col in data.columns:
    data[col] = encodeur.fit_transform(data[col])

# %%
X = data.iloc[:,1:23] #les caractéristiques
y = data.iloc[:, 0]  #les résulats (classes)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.naive_bayes import MultinomialNB

modele = MultinomialNB()
modele.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = modele.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("précision: ", accuracy_score(y_test, y_pred))
# Out:
# précision:  0.788923076923077

# %%
from joblib import dump
...
modele.fit(X_train, y_train)
dump(modele, 'mon_modele.joblib')
# Out:
# ['mon_modele.joblib']

# %%
from joblib import load
...
modele = load('mon_modele.joblib')
y_pred2 = modele.predict(X_test)
y_pred2
# Out:
# array([1, 0, 1, ..., 0, 0, 1])
